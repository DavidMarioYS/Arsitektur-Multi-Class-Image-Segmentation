# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Admin\\Documents\\SKRIPSI\\Kode\\Model'

# %% [markdown]
# # Informasi Dataset

# %%
# Path ke folder 'original'
ori_folder = 'C:\\Users\\Admin\\Documents\\SKRIPSI\\DATASET\\ORI'
gt_folder = 'C:\\Users\\Admin\\Documents\\SKRIPSI\\DATASET\\GT'

def get_file_formats(folder_path):
  """
  Fungsi untuk mendapatkan format file yang ada di dalam folder.
  """
  formats = set()
  for filename in os.listdir(folder_path):
    formats.add(filename.split('.')[-1].lower())
  return list(formats)

print(f"\nJumlah data di folder original: {len(os.listdir(ori_folder))}")
print(f"Jumlah data di folder ground_truth: {len(os.listdir(gt_folder))}")

print(f"\nFormat file di folder original: {get_file_formats(ori_folder)}")
print(f"Format file di folder ground_truth: {get_file_formats(gt_folder)}")
# Out:
# Jumlah data di folder original: 115
# Jumlah data di folder ground_truth: 115
#
# Format file di folder original: ['png']
# Format file di folder ground_truth: ['png']

# %%
import os
import numpy as np
from PIL import Image

# Fungsi untuk mendapatkan informasi detail dari gambar
def get_image_info(image_path):
    with Image.open(image_path) as img:
        img_format = img.format  # Format gambar (misal: JPEG, PNG)
        img_size = img.size      # Ukuran gambar (width, height)
        img_mode = img.mode      # Mode gambar (misal: RGB, L, RGBA)

        # Mengonversi gambar ke array numpy untuk mendapatkan shape
        img_array = np.array(img)
        img_shape = img_array.shape

        img_info = {
            "Format": img_format,
            "Ukuran (Width x Height)": img_size,
            "Mode Warna": img_mode,
            "Total Pixel": img_size[0] * img_size[1],
            "Shape": img_shape
        }
        return img_info

# Mengurutkan file berdasarkan nama di folder original
image_files = sorted([f for f in os.listdir(ori_folder) if f.endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff'))])

# Menampilkan informasi detail setiap gambar di folder original
for image_file in image_files:
    image_path = os.path.join(ori_folder, image_file)
    info = get_image_info(image_path)
    print(f"\nInformasi Gambar: {image_file}")
    for key, value in info.items():
        print(f"{key}: {value}")

# Mengurutkan file berdasarkan nama di folder ground_truth
label_files = sorted([f for f in os.listdir(gt_folder) if f.endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff'))])

# Menampilkan informasi detail setiap gambar di folder ground_truth
for label_file in label_files:
    label_path = os.path.join(gt_folder, label_file)
    info = get_image_info(label_path)
    print(f"\nInformasi Gambar Ground Truth: {label_file}")
    for key, value in info.items():
        print(f"{key}: {value}")
# Out:
# Informasi Gambar: Img_001.png
# Format: PNG
# Ukuran (Width x Height): (600, 600)
# Mode Warna: RGB
# Total Pixel: 360000
# Shape: (600, 600, 3)
#
# Informasi Gambar: Img_002.png
# Format: PNG
# Ukuran (Width x Height): (800, 450)
# Mode Warna: RGB
# Total Pixel: 360000
# Shape: (450, 800, 3)
#
# Informasi Gambar: Img_003.png
# Format: PNG
# Ukuran (Width x Height): (1942, 1456)
# Mode Warna: RGB
# Total Pixel: 2827552
# Shape: (1456, 1942, 3)
#
# Informasi Gambar: Img_004.png
# Format: PNG
# Ukuran (Width x Height): (600, 600)
# Mode Warna: RGB
# Total Pixel: 360000
# Shape: (600, 600, 3)
#
# Informasi Gambar: Img_005.png
# Format: PNG
# Ukuran (Width x Height): (600, 600)
# Mode Warna: RGB
# Total Pixel: 360000
# Shape: (600, 600, 3)
#
# Informasi Gambar: Img_006.png
# Format: PNG
# Ukuran (Width x Height): (2304, 1536)
# Mode Warna: RGB
# Total Pixel: 3538944
# Shape: (1536, 2304, 3)
#
# Informasi Gambar: Img_007.png
# Format: PNG
# Ukuran (Width x Height): (428, 288)
# Mode Warna: RGB
# Total Pixel: 123264
# Shape: (288, 428, 3)
#
# Informasi Gambar: Img_008.png
# Format: PNG
# Ukuran (Width x Height): (600, 670)
# Mode Warna: RGB
# Total Pixel: 402000
# Shape: (670, 600, 3)
#
# Informasi Gambar: Img_009.png
# Format: PNG
# Ukuran (Width x Height): (480, 320)
# Mode Warna: RGB
# Total Pixel: 153600
# Shape: (320, 480, 3)
#
# Informasi Gambar: Img_010.png
# Format: PNG
# Ukuran (Width x Height): (778, 579)
# Mode Warna: RGB
# Total Pixel: 450462
# Shape: (579, 778, 3)
#
# Informasi Gambar: Img_011.png
# Format: PNG
# Ukuran (Width x Height): (640, 426)
# Mode Warna: RGB
# Total Pixel: 272640
# Shape: (426, 640, 3)
#
# Informasi Gambar: Img_012.png
# Format: PNG
# Ukuran (Width x Height): (640, 596)
# Mode Warna: RGB
# Total Pixel: 381440
# Shape: (596, 640, 3)
#
# Informasi Gambar: Img_013.png
# Format: PNG
# Ukuran (Width x Height): (640, 640)
# Mode Warna: RGB
# Total Pixel: 409600
# Shape: (640, 640, 3)
#
# Informasi Gambar: Img_014.png
# Format: PNG
# Ukuran (Width x Height): (600, 600)
# Mode Warna: RGB
# Total Pixel: 360000
# Shape: (600, 600, 3)
#
# Informasi Gambar: Img_015.png
# Format: PNG
# Ukuran (Width x Height): (640, 640)
# Mode Warna: RGB
# Total Pixel: 409600
# Shape: (640, 640, 3)
#
# Informasi Gambar: Img_016.png
# Format: PNG
# Ukuran (Width x Height): (640, 640)
# Mode Warna: RGB
# Total Pixel: 409600
# Shape: (640, 640, 3)
#
# Informasi Gambar: Img_017.png
# Format: PNG
# Ukuran (Width x Height): (600, 600)
# Mode Warna: RGB
# Total Pixel: 360000
# Shape: (600, 600, 3)
#
# Informasi Gambar: Img_018.png
# Format: PNG
# Ukuran (Width x Height): (600, 600)
# Mode Warna: RGB
# Total Pixel: 360000
# Shape: (600, 600, 3)
#
# Informasi Gambar: Img_019.png
# Format: PNG
# Ukuran (Width x Height): (600, 600)
# Mode Warna: RGB
# Total Pixel: 360000
# Shape: (600, 600, 3)
#
# Informasi Gambar: Img_020.png
# Format: PNG
# Ukuran (Width x Height): (600, 600)
# Mode Warna: RGB
# Total Pixel: 360000
# Shape: (600, 600, 3)
#
# Informasi Gambar: Img_021.png
# Format: PNG
# Ukuran (Width x Height): (600, 600)
# Mode Warna: RGB
# Total Pixel: 360000
# Shape: (600, 600, 3)
#
# Informasi Gambar: Img_022.png
# Format: PNG
# Ukuran (Width x Height): (600, 600)
# Mode Warna: RGB
# Total Pixel: 360000
# Shape: (600, 600, 3)
#
# Informasi Gambar: Img_023.png
# Format: PNG
# Ukuran (Width x Height): (600, 600)
# Mode Warna: RGB
# Total Pixel: 360000
# Shape: (600, 600, 3)
#
# Informasi Gambar: Img_024.png
# Format: PNG
# Ukuran (Width x Height): (600, 600)
# Mode Warna: RGB
# Total Pixel: 360000
# Shape: (600, 600, 3)
#
# Informasi Gambar: Img_025.png
# Format: PNG
# Ukuran (Width x Height): (600, 536)
# Mode Warna: RGB
# Total Pixel: 321600
# Shape: (536, 600, 3)
#
# Informasi Gambar: Img_026.png
# Format: PNG
# Ukuran (Width x Height): (600, 600)
# Mode Warna: RGB
# Total Pixel: 360000
# Shape: (600, 600, 3)
#
# Informasi Gambar: Img_027.png
# Format: PNG
# Ukuran (Width x Height): (600, 600)
# Mode Warna: RGB
# Total Pixel: 360000
# Shape: (600, 600, 3)
#
# Informasi Gambar: Img_028.png
# Format: PNG
# Ukuran (Width x Height): (640, 584)
# Mode Warna: RGB
# Total Pixel: 373760
# Shape: (584, 640, 3)
#
# Informasi Gambar: Img_029.png
# Format: PNG
# Ukuran (Width x Height): (640, 580)
# Mode Warna: RGB
# Total Pixel: 371200
# Shape: (580, 640, 3)
#
# Informasi Gambar: Img_030.png
# Format: PNG
# Ukuran (Width x Height): (640, 567)
# Mode Warna: RGB
# Total Pixel: 362880
# Shape: (567, 640, 3)
#
# Informasi Gambar: Img_031.png
# Format: PNG
# Ukuran (Width x Height): (640, 570)
# Mode Warna: RGB
# Total Pixel: 364800
# Shape: (570, 640, 3)
#
# Informasi Gambar: Img_032.png
# Format: PNG
# Ukuran (Width x Height): (640, 584)
# Mode Warna: RGB
# Total Pixel: 373760
# Shape: (584, 640, 3)
#
# Informasi Gambar: Img_033.png
# Format: PNG
# Ukuran (Width x Height): (640, 584)
# Mode Warna: RGB
# Total Pixel: 373760
# Shape: (584, 640, 3)
#
# Informasi Gambar: Img_034.png
# Format: PNG
# Ukuran (Width x Height): (600, 450)
# Mode Warna: RGB
# Total Pixel: 270000
# Shape: (450, 600, 3)
#
# Informasi Gambar: Img_035.png
# Format: PNG
# Ukuran (Width x Height): (640, 574)
# Mode Warna: RGB
# Total Pixel: 367360
# Shape: (574, 640, 3)
#
# Informasi Gambar: Img_036.png
# Format: PNG
# Ukuran (Width x Height): (640, 594)
# Mode Warna: RGB
# Total Pixel: 380160
# Shape: (594, 640, 3)
#
# Informasi Gambar: Img_037.png
# Format: PNG
# Ukuran (Width x Height): (1980, 1485)
# Mode Warna: RGB
# Total Pixel: 2940300
# Shape: (1485, 1980, 3)
#
# Informasi Gambar: Img_038.png
# Format: PNG
# Ukuran (Width x Height): (1080, 675)
# Mode Warna: RGB
# Total Pixel: 729000
# Shape: (675, 1080, 3)
#
# Informasi Gambar: Img_039.png
# Format: PNG
# Ukuran (Width x Height): (1024, 683)
# Mode Warna: RGB
# Total Pixel: 699392
# Shape: (683, 1024, 3)
#
# Informasi Gambar: Img_040.png
# Format: PNG
# Ukuran (Width x Height): (276, 182)
# Mode Warna: RGB
# Total Pixel: 50232
# Shape: (182, 276, 3)
#
# Informasi Gambar: Img_041.png
# Format: PNG
# Ukuran (Width x Height): (640, 580)
# Mode Warna: RGB
# Total Pixel: 371200
# Shape: (580, 640, 3)
#
# Informasi Gambar: Img_042.png
# Format: PNG
# Ukuran (Width x Height): (3024, 4032)
# Mode Warna: RGB
# Total Pixel: 12192768
# Shape: (4032, 3024, 3)
#
# Informasi Gambar: Img_043.png
# Format: PNG
# Ukuran (Width x Height): (225, 300)
# Mode Warna: RGB
# Total Pixel: 67500
# Shape: (300, 225, 3)
#
# Informasi Gambar: Img_044.png
# Format: PNG
# Ukuran (Width x Height): (2240, 1260)
# Mode Warna: RGB
# Total Pixel: 2822400
# Shape: (1260, 2240, 3)
#
# Informasi Gambar: Img_045.png
# Format: PNG
# Ukuran (Width x Height): (2048, 1536)
# Mode Warna: RGB
# Total Pixel: 3145728
# Shape: (1536, 2048, 3)
#
# Informasi Gambar: Img_046.png
# Format: PNG
# Ukuran (Width x Height): (1300, 863)
# Mode Warna: RGB
# Total Pixel: 1121900
# Shape: (863, 1300, 3)
#
# Informasi Gambar: Img_047.png
# Format: PNG
# Ukuran (Width x Height): (397, 450)
# Mode Warna: RGB
# Total Pixel: 178650
# Shape: (450, 397, 3)
#
# Informasi Gambar: Img_048.png
# Format: PNG
# Ukuran (Width x Height): (1300, 975)
# Mode Warna: RGB
# Total Pixel: 1267500
# Shape: (975, 1300, 3)
#
# Informasi Gambar: Img_049.png
# Format: PNG
# Ukuran (Width x Height): (640, 566)
# Mode Warna: RGB
# Total Pixel: 362240
# Shape: (566, 640, 3)
#
# Informasi Gambar: Img_050.png
# Format: PNG
# Ukuran (Width x Height): (600, 800)
# Mode Warna: RGB
# Total Pixel: 480000
# Shape: (800, 600, 3)
#
# Informasi Gambar: Img_051.png
# Format: PNG
# Ukuran (Width x Height): (800, 600)
# Mode Warna: RGB
# Total Pixel: 480000
# Shape: (600, 800, 3)
#
# Informasi Gambar: Img_052.png
# Format: PNG
# Ukuran (Width x Height): (800, 600)
# Mode Warna: RGB
# Total Pixel: 480000
# Shape: (600, 800, 3)
#
# Informasi Gambar: Img_053.png
# Format: PNG
# Ukuran (Width x Height): (600, 800)
# Mode Warna: RGB
# Total Pixel: 480000
# Shape: (800, 600, 3)
#
# Informasi Gambar: Img_054.png
# Format: PNG
# Ukuran (Width x Height): (843, 1124)
# Mode Warna: RGB
# Total Pixel: 947532
# Shape: (1124, 843, 3)
#
# Informasi Gambar: Img_055.png
# Format: PNG
# Ukuran (Width x Height): (843, 1124)
# Mode Warna: RGB
# Total Pixel: 947532
# Shape: (1124, 843, 3)
#
# Informasi Gambar: Img_056.png
# Format: PNG
# Ukuran (Width x Height): (843, 1124)
# Mode Warna: RGB
# Total Pixel: 947532
# Shape: (1124, 843, 3)
#
# Informasi Gambar: Img_057.png
# Format: PNG
# Ukuran (Width x Height): (600, 600)
# Mode Warna: RGB
# Total Pixel: 360000
# Shape: (600, 600, 3)
#
# Informasi Gambar: Img_058.png
# Format: PNG
# Ukuran (Width x Height): (6000, 8000)
# Mode Warna: RGB
# Total Pixel: 48000000
# Shape: (8000, 6000, 3)
#
# Informasi Gambar: Img_059.png
# Format: PNG
# Ukuran (Width x Height): (6000, 8000)
# Mode Warna: RGB
# Total Pixel: 48000000
# Shape: (8000, 6000, 3)
#
# Informasi Gambar: Img_060.png
# Format: PNG
# Ukuran (Width x Height): (6000, 8000)
# Mode Warna: RGB
# Total Pixel: 48000000
# Shape: (8000, 6000, 3)
#
# Informasi Gambar: Img_061.png
# Format: PNG
# Ukuran (Width x Height): (3120, 4160)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (4160, 3120, 3)
#
# Informasi Gambar: Img_062.png
# Format: PNG
# Ukuran (Width x Height): (4160, 3120)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (3120, 4160, 3)
#
# Informasi Gambar: Img_063.png
# Format: PNG
# Ukuran (Width x Height): (3120, 4160)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (4160, 3120, 3)
#
# Informasi Gambar: Img_064.png
# Format: PNG
# Ukuran (Width x Height): (3120, 4160)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (4160, 3120, 3)
#
# Informasi Gambar: Img_065.png
# Format: PNG
# Ukuran (Width x Height): (3120, 4160)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (4160, 3120, 3)
#
# Informasi Gambar: Img_066.png
# Format: PNG
# Ukuran (Width x Height): (3120, 4160)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (4160, 3120, 3)
#
# Informasi Gambar: Img_067.png
# Format: PNG
# Ukuran (Width x Height): (4160, 3120)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (3120, 4160, 3)
#
# Informasi Gambar: Img_068.png
# Format: PNG
# Ukuran (Width x Height): (4160, 3120)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (3120, 4160, 3)
#
# Informasi Gambar: Img_069.png
# Format: PNG
# Ukuran (Width x Height): (3120, 4160)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (4160, 3120, 3)
#
# Informasi Gambar: Img_070.png
# Format: PNG
# Ukuran (Width x Height): (3120, 4160)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (4160, 3120, 3)
#
# Informasi Gambar: Img_071.png
# Format: PNG
# Ukuran (Width x Height): (3120, 4160)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (4160, 3120, 3)
#
# Informasi Gambar: Img_072.png
# Format: PNG
# Ukuran (Width x Height): (3120, 4160)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (4160, 3120, 3)
#
# Informasi Gambar: Img_073.png
# Format: PNG
# Ukuran (Width x Height): (3120, 4160)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (4160, 3120, 3)
#
# Informasi Gambar: Img_074.png
# Format: PNG
# Ukuran (Width x Height): (3120, 4160)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (4160, 3120, 3)
#
# Informasi Gambar: Img_075.png
# Format: PNG
# Ukuran (Width x Height): (3120, 4160)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (4160, 3120, 3)
#
# Informasi Gambar: Img_076.png
# Format: PNG
# Ukuran (Width x Height): (4160, 3120)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (3120, 4160, 3)
#
# Informasi Gambar: Img_077.png
# Format: PNG
# Ukuran (Width x Height): (4160, 3120)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (3120, 4160, 3)
#
# Informasi Gambar: Img_078.png
# Format: PNG
# Ukuran (Width x Height): (3120, 4160)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (4160, 3120, 3)
#
# Informasi Gambar: Img_079.png
# Format: PNG
# Ukuran (Width x Height): (3120, 4160)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (4160, 3120, 3)
#
# Informasi Gambar: Img_080.png
# Format: PNG
# Ukuran (Width x Height): (3120, 4160)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (4160, 3120, 3)
#
# Informasi Gambar: Img_081.png
# Format: PNG
# Ukuran (Width x Height): (3120, 4160)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (4160, 3120, 3)
#
# Informasi Gambar: Img_082.png
# Format: PNG
# Ukuran (Width x Height): (3120, 4160)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (4160, 3120, 3)
#
# Informasi Gambar: Img_083.png
# Format: PNG
# Ukuran (Width x Height): (3120, 4160)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (4160, 3120, 3)
#
# Informasi Gambar: Img_084.png
# Format: PNG
# Ukuran (Width x Height): (798, 940)
# Mode Warna: RGB
# Total Pixel: 750120
# Shape: (940, 798, 3)
#
# Informasi Gambar: Img_085.png
# Format: PNG
# Ukuran (Width x Height): (1024, 865)
# Mode Warna: RGB
# Total Pixel: 885760
# Shape: (865, 1024, 3)
#
# Informasi Gambar: Img_086.png
# Format: PNG
# Ukuran (Width x Height): (1024, 1024)
# Mode Warna: RGB
# Total Pixel: 1048576
# Shape: (1024, 1024, 3)
#
# Informasi Gambar: Img_087.png
# Format: PNG
# Ukuran (Width x Height): (1024, 1024)
# Mode Warna: RGB
# Total Pixel: 1048576
# Shape: (1024, 1024, 3)
#
# Informasi Gambar: Img_088.png
# Format: PNG
# Ukuran (Width x Height): (1024, 1024)
# Mode Warna: RGB
# Total Pixel: 1048576
# Shape: (1024, 1024, 3)
#
# Informasi Gambar: Img_089.png
# Format: PNG
# Ukuran (Width x Height): (1024, 768)
# Mode Warna: RGB
# Total Pixel: 786432
# Shape: (768, 1024, 3)
#
# Informasi Gambar: Img_090.png
# Format: PNG
# Ukuran (Width x Height): (1024, 518)
# Mode Warna: RGB
# Total Pixel: 530432
# Shape: (518, 1024, 3)
#
# Informasi Gambar: Img_091.png
# Format: PNG
# Ukuran (Width x Height): (696, 502)
# Mode Warna: RGB
# Total Pixel: 349392
# Shape: (502, 696, 3)
#
# Informasi Gambar: Img_092.png
# Format: PNG
# Ukuran (Width x Height): (874, 438)
# Mode Warna: RGB
# Total Pixel: 382812
# Shape: (438, 874, 3)
#
# Informasi Gambar: Img_093.png
# Format: PNG
# Ukuran (Width x Height): (588, 500)
# Mode Warna: RGB
# Total Pixel: 294000
# Shape: (500, 588, 3)
#
# Informasi Gambar: Img_094.png
# Format: PNG
# Ukuran (Width x Height): (1024, 631)
# Mode Warna: RGB
# Total Pixel: 646144
# Shape: (631, 1024, 3)
#
# Informasi Gambar: Img_095.png
# Format: PNG
# Ukuran (Width x Height): (1024, 1024)
# Mode Warna: RGB
# Total Pixel: 1048576
# Shape: (1024, 1024, 3)
#
# Informasi Gambar: Img_096.png
# Format: PNG
# Ukuran (Width x Height): (1024, 883)
# Mode Warna: RGB
# Total Pixel: 904192
# Shape: (883, 1024, 3)
#
# Informasi Gambar: Img_097.png
# Format: PNG
# Ukuran (Width x Height): (1024, 682)
# Mode Warna: RGB
# Total Pixel: 698368
# Shape: (682, 1024, 3)
#
# Informasi Gambar: Img_098.png
# Format: PNG
# Ukuran (Width x Height): (920, 506)
# Mode Warna: RGB
# Total Pixel: 465520
# Shape: (506, 920, 3)
#
# Informasi Gambar: Img_099.png
# Format: PNG
# Ukuran (Width x Height): (908, 504)
# Mode Warna: RGB
# Total Pixel: 457632
# Shape: (504, 908, 3)
#
# Informasi Gambar: Img_100.png
# Format: PNG
# Ukuran (Width x Height): (954, 502)
# Mode Warna: RGB
# Total Pixel: 478908
# Shape: (502, 954, 3)
#
# Informasi Gambar: Img_101.png
# Format: PNG
# Ukuran (Width x Height): (1024, 862)
# Mode Warna: RGB
# Total Pixel: 882688
# Shape: (862, 1024, 3)
#
# Informasi Gambar: Img_102.png
# Format: PNG
# Ukuran (Width x Height): (881, 758)
# Mode Warna: RGB
# Total Pixel: 667798
# Shape: (758, 881, 3)
#
# Informasi Gambar: Img_103.png
# Format: PNG
# Ukuran (Width x Height): (874, 856)
# Mode Warna: RGB
# Total Pixel: 748144
# Shape: (856, 874, 3)
#
# Informasi Gambar: Img_104.png
# Format: PNG
# Ukuran (Width x Height): (1024, 829)
# Mode Warna: RGB
# Total Pixel: 848896
# Shape: (829, 1024, 3)
#
# Informasi Gambar: Img_105.png
# Format: PNG
# Ukuran (Width x Height): (1024, 787)
# Mode Warna: RGB
# Total Pixel: 805888
# Shape: (787, 1024, 3)
#
# Informasi Gambar: Img_106.png
# Format: PNG
# Ukuran (Width x Height): (754, 658)
# Mode Warna: RGB
# Total Pixel: 496132
# Shape: (658, 754, 3)
#
# Informasi Gambar: Img_107.png
# Format: PNG
# Ukuran (Width x Height): (607, 796)
# Mode Warna: RGB
# Total Pixel: 483172
# Shape: (796, 607, 3)
#
# Informasi Gambar: Img_108.png
# Format: PNG
# Ukuran (Width x Height): (1024, 751)
# Mode Warna: RGB
# Total Pixel: 769024
# Shape: (751, 1024, 3)
#
# Informasi Gambar: Img_109.png
# Format: PNG
# Ukuran (Width x Height): (640, 512)
# Mode Warna: RGB
# Total Pixel: 327680
# Shape: (512, 640, 3)
#
# Informasi Gambar: Img_110.png
# Format: PNG
# Ukuran (Width x Height): (822, 424)
# Mode Warna: RGB
# Total Pixel: 348528
# Shape: (424, 822, 3)
#
# Informasi Gambar: Img_111.png
# Format: PNG
# Ukuran (Width x Height): (736, 438)
# Mode Warna: RGB
# Total Pixel: 322368
# Shape: (438, 736, 3)
#
# Informasi Gambar: Img_112.png
# Format: PNG
# Ukuran (Width x Height): (762, 316)
# Mode Warna: RGB
# Total Pixel: 240792
# Shape: (316, 762, 3)
#
# Informasi Gambar: Img_113.png
# Format: PNG
# Ukuran (Width x Height): (600, 715)
# Mode Warna: RGB
# Total Pixel: 429000
# Shape: (715, 600, 3)
#
# Informasi Gambar: Img_114.png
# Format: PNG
# Ukuran (Width x Height): (570, 664)
# Mode Warna: RGB
# Total Pixel: 378480
# Shape: (664, 570, 3)
#
# Informasi Gambar: Img_115.png
# Format: PNG
# Ukuran (Width x Height): (426, 696)
# Mode Warna: RGB
# Total Pixel: 296496
# Shape: (696, 426, 3)
#
# Informasi Gambar Ground Truth: Img_001.png
# Format: PNG
# Ukuran (Width x Height): (600, 600)
# Mode Warna: RGB
# Total Pixel: 360000
# Shape: (600, 600, 3)
#
# Informasi Gambar Ground Truth: Img_002.png
# Format: PNG
# Ukuran (Width x Height): (800, 450)
# Mode Warna: RGB
# Total Pixel: 360000
# Shape: (450, 800, 3)
#
# Informasi Gambar Ground Truth: Img_003.png
# Format: PNG
# Ukuran (Width x Height): (1942, 1456)
# Mode Warna: RGB
# Total Pixel: 2827552
# Shape: (1456, 1942, 3)
#
# Informasi Gambar Ground Truth: Img_004.png
# Format: PNG
# Ukuran (Width x Height): (600, 600)
# Mode Warna: RGB
# Total Pixel: 360000
# Shape: (600, 600, 3)
#
# Informasi Gambar Ground Truth: Img_005.png
# Format: PNG
# Ukuran (Width x Height): (600, 600)
# Mode Warna: RGB
# Total Pixel: 360000
# Shape: (600, 600, 3)
#
# Informasi Gambar Ground Truth: Img_006.png
# Format: PNG
# Ukuran (Width x Height): (2304, 1536)
# Mode Warna: RGB
# Total Pixel: 3538944
# Shape: (1536, 2304, 3)
#
# Informasi Gambar Ground Truth: Img_007.png
# Format: PNG
# Ukuran (Width x Height): (428, 288)
# Mode Warna: RGB
# Total Pixel: 123264
# Shape: (288, 428, 3)
#
# Informasi Gambar Ground Truth: Img_008.png
# Format: PNG
# Ukuran (Width x Height): (600, 670)
# Mode Warna: RGB
# Total Pixel: 402000
# Shape: (670, 600, 3)
#
# Informasi Gambar Ground Truth: Img_009.png
# Format: PNG
# Ukuran (Width x Height): (480, 320)
# Mode Warna: RGB
# Total Pixel: 153600
# Shape: (320, 480, 3)
#
# Informasi Gambar Ground Truth: Img_010.png
# Format: PNG
# Ukuran (Width x Height): (778, 579)
# Mode Warna: RGB
# Total Pixel: 450462
# Shape: (579, 778, 3)
#
# Informasi Gambar Ground Truth: Img_011.png
# Format: PNG
# Ukuran (Width x Height): (640, 426)
# Mode Warna: RGB
# Total Pixel: 272640
# Shape: (426, 640, 3)
#
# Informasi Gambar Ground Truth: Img_012.png
# Format: PNG
# Ukuran (Width x Height): (640, 596)
# Mode Warna: RGB
# Total Pixel: 381440
# Shape: (596, 640, 3)
#
# Informasi Gambar Ground Truth: Img_013.png
# Format: PNG
# Ukuran (Width x Height): (640, 640)
# Mode Warna: RGB
# Total Pixel: 409600
# Shape: (640, 640, 3)
#
# Informasi Gambar Ground Truth: Img_014.png
# Format: PNG
# Ukuran (Width x Height): (600, 600)
# Mode Warna: RGB
# Total Pixel: 360000
# Shape: (600, 600, 3)
#
# Informasi Gambar Ground Truth: Img_015.png
# Format: PNG
# Ukuran (Width x Height): (640, 640)
# Mode Warna: RGB
# Total Pixel: 409600
# Shape: (640, 640, 3)
#
# Informasi Gambar Ground Truth: Img_016.png
# Format: PNG
# Ukuran (Width x Height): (640, 640)
# Mode Warna: RGB
# Total Pixel: 409600
# Shape: (640, 640, 3)
#
# Informasi Gambar Ground Truth: Img_017.png
# Format: PNG
# Ukuran (Width x Height): (600, 600)
# Mode Warna: RGB
# Total Pixel: 360000
# Shape: (600, 600, 3)
#
# Informasi Gambar Ground Truth: Img_018.png
# Format: PNG
# Ukuran (Width x Height): (600, 600)
# Mode Warna: RGB
# Total Pixel: 360000
# Shape: (600, 600, 3)
#
# Informasi Gambar Ground Truth: Img_019.png
# Format: PNG
# Ukuran (Width x Height): (600, 600)
# Mode Warna: RGB
# Total Pixel: 360000
# Shape: (600, 600, 3)
#
# Informasi Gambar Ground Truth: Img_020.png
# Format: PNG
# Ukuran (Width x Height): (600, 600)
# Mode Warna: RGB
# Total Pixel: 360000
# Shape: (600, 600, 3)
#
# Informasi Gambar Ground Truth: Img_021.png
# Format: PNG
# Ukuran (Width x Height): (600, 600)
# Mode Warna: RGB
# Total Pixel: 360000
# Shape: (600, 600, 3)
#
# Informasi Gambar Ground Truth: Img_022.png
# Format: PNG
# Ukuran (Width x Height): (600, 600)
# Mode Warna: RGB
# Total Pixel: 360000
# Shape: (600, 600, 3)
#
# Informasi Gambar Ground Truth: Img_023.png
# Format: PNG
# Ukuran (Width x Height): (600, 600)
# Mode Warna: RGB
# Total Pixel: 360000
# Shape: (600, 600, 3)
#
# Informasi Gambar Ground Truth: Img_024.png
# Format: PNG
# Ukuran (Width x Height): (600, 600)
# Mode Warna: RGB
# Total Pixel: 360000
# Shape: (600, 600, 3)
#
# Informasi Gambar Ground Truth: Img_025.png
# Format: PNG
# Ukuran (Width x Height): (600, 536)
# Mode Warna: RGB
# Total Pixel: 321600
# Shape: (536, 600, 3)
#
# Informasi Gambar Ground Truth: Img_026.png
# Format: PNG
# Ukuran (Width x Height): (600, 600)
# Mode Warna: RGB
# Total Pixel: 360000
# Shape: (600, 600, 3)
#
# Informasi Gambar Ground Truth: Img_027.png
# Format: PNG
# Ukuran (Width x Height): (600, 600)
# Mode Warna: RGB
# Total Pixel: 360000
# Shape: (600, 600, 3)
#
# Informasi Gambar Ground Truth: Img_028.png
# Format: PNG
# Ukuran (Width x Height): (640, 584)
# Mode Warna: RGB
# Total Pixel: 373760
# Shape: (584, 640, 3)
#
# Informasi Gambar Ground Truth: Img_029.png
# Format: PNG
# Ukuran (Width x Height): (640, 580)
# Mode Warna: RGB
# Total Pixel: 371200
# Shape: (580, 640, 3)
#
# Informasi Gambar Ground Truth: Img_030.png
# Format: PNG
# Ukuran (Width x Height): (640, 567)
# Mode Warna: RGB
# Total Pixel: 362880
# Shape: (567, 640, 3)
#
# Informasi Gambar Ground Truth: Img_031.png
# Format: PNG
# Ukuran (Width x Height): (640, 570)
# Mode Warna: RGB
# Total Pixel: 364800
# Shape: (570, 640, 3)
#
# Informasi Gambar Ground Truth: Img_032.png
# Format: PNG
# Ukuran (Width x Height): (640, 584)
# Mode Warna: RGB
# Total Pixel: 373760
# Shape: (584, 640, 3)
#
# Informasi Gambar Ground Truth: Img_033.png
# Format: PNG
# Ukuran (Width x Height): (640, 584)
# Mode Warna: RGB
# Total Pixel: 373760
# Shape: (584, 640, 3)
#
# Informasi Gambar Ground Truth: Img_034.png
# Format: PNG
# Ukuran (Width x Height): (600, 450)
# Mode Warna: RGB
# Total Pixel: 270000
# Shape: (450, 600, 3)
#
# Informasi Gambar Ground Truth: Img_035.png
# Format: PNG
# Ukuran (Width x Height): (640, 574)
# Mode Warna: RGB
# Total Pixel: 367360
# Shape: (574, 640, 3)
#
# Informasi Gambar Ground Truth: Img_036.png
# Format: PNG
# Ukuran (Width x Height): (640, 594)
# Mode Warna: RGB
# Total Pixel: 380160
# Shape: (594, 640, 3)
#
# Informasi Gambar Ground Truth: Img_037.png
# Format: PNG
# Ukuran (Width x Height): (1980, 1485)
# Mode Warna: RGB
# Total Pixel: 2940300
# Shape: (1485, 1980, 3)
#
# Informasi Gambar Ground Truth: Img_038.png
# Format: PNG
# Ukuran (Width x Height): (1080, 675)
# Mode Warna: RGB
# Total Pixel: 729000
# Shape: (675, 1080, 3)
#
# Informasi Gambar Ground Truth: Img_039.png
# Format: PNG
# Ukuran (Width x Height): (1024, 683)
# Mode Warna: RGB
# Total Pixel: 699392
# Shape: (683, 1024, 3)
#
# Informasi Gambar Ground Truth: Img_040.png
# Format: PNG
# Ukuran (Width x Height): (276, 182)
# Mode Warna: RGB
# Total Pixel: 50232
# Shape: (182, 276, 3)
#
# Informasi Gambar Ground Truth: Img_041.png
# Format: PNG
# Ukuran (Width x Height): (640, 580)
# Mode Warna: RGB
# Total Pixel: 371200
# Shape: (580, 640, 3)
#
# Informasi Gambar Ground Truth: Img_042.png
# Format: PNG
# Ukuran (Width x Height): (3024, 4032)
# Mode Warna: RGB
# Total Pixel: 12192768
# Shape: (4032, 3024, 3)
#
# Informasi Gambar Ground Truth: Img_043.png
# Format: PNG
# Ukuran (Width x Height): (225, 300)
# Mode Warna: RGB
# Total Pixel: 67500
# Shape: (300, 225, 3)
#
# Informasi Gambar Ground Truth: Img_044.png
# Format: PNG
# Ukuran (Width x Height): (2240, 1260)
# Mode Warna: RGB
# Total Pixel: 2822400
# Shape: (1260, 2240, 3)
#
# Informasi Gambar Ground Truth: Img_045.png
# Format: PNG
# Ukuran (Width x Height): (2048, 1536)
# Mode Warna: RGB
# Total Pixel: 3145728
# Shape: (1536, 2048, 3)
#
# Informasi Gambar Ground Truth: Img_046.png
# Format: PNG
# Ukuran (Width x Height): (1300, 863)
# Mode Warna: RGB
# Total Pixel: 1121900
# Shape: (863, 1300, 3)
#
# Informasi Gambar Ground Truth: Img_047.png
# Format: PNG
# Ukuran (Width x Height): (397, 450)
# Mode Warna: RGB
# Total Pixel: 178650
# Shape: (450, 397, 3)
#
# Informasi Gambar Ground Truth: Img_048.png
# Format: PNG
# Ukuran (Width x Height): (1300, 975)
# Mode Warna: RGB
# Total Pixel: 1267500
# Shape: (975, 1300, 3)
#
# Informasi Gambar Ground Truth: Img_049.png
# Format: PNG
# Ukuran (Width x Height): (640, 566)
# Mode Warna: RGB
# Total Pixel: 362240
# Shape: (566, 640, 3)
#
# Informasi Gambar Ground Truth: Img_050.png
# Format: PNG
# Ukuran (Width x Height): (600, 800)
# Mode Warna: RGB
# Total Pixel: 480000
# Shape: (800, 600, 3)
#
# Informasi Gambar Ground Truth: Img_051.png
# Format: PNG
# Ukuran (Width x Height): (800, 600)
# Mode Warna: RGB
# Total Pixel: 480000
# Shape: (600, 800, 3)
#
# Informasi Gambar Ground Truth: Img_052.png
# Format: PNG
# Ukuran (Width x Height): (800, 600)
# Mode Warna: RGB
# Total Pixel: 480000
# Shape: (600, 800, 3)
#
# Informasi Gambar Ground Truth: Img_053.png
# Format: PNG
# Ukuran (Width x Height): (600, 800)
# Mode Warna: RGB
# Total Pixel: 480000
# Shape: (800, 600, 3)
#
# Informasi Gambar Ground Truth: Img_054.png
# Format: PNG
# Ukuran (Width x Height): (843, 1124)
# Mode Warna: RGB
# Total Pixel: 947532
# Shape: (1124, 843, 3)
#
# Informasi Gambar Ground Truth: Img_055.png
# Format: PNG
# Ukuran (Width x Height): (843, 1124)
# Mode Warna: RGB
# Total Pixel: 947532
# Shape: (1124, 843, 3)
#
# Informasi Gambar Ground Truth: Img_056.png
# Format: PNG
# Ukuran (Width x Height): (843, 1124)
# Mode Warna: RGB
# Total Pixel: 947532
# Shape: (1124, 843, 3)
#
# Informasi Gambar Ground Truth: Img_057.png
# Format: PNG
# Ukuran (Width x Height): (600, 600)
# Mode Warna: RGB
# Total Pixel: 360000
# Shape: (600, 600, 3)
#
# Informasi Gambar Ground Truth: Img_058.png
# Format: PNG
# Ukuran (Width x Height): (6000, 8000)
# Mode Warna: RGB
# Total Pixel: 48000000
# Shape: (8000, 6000, 3)
#
# Informasi Gambar Ground Truth: Img_059.png
# Format: PNG
# Ukuran (Width x Height): (6000, 8000)
# Mode Warna: RGB
# Total Pixel: 48000000
# Shape: (8000, 6000, 3)
#
# Informasi Gambar Ground Truth: Img_060.png
# Format: PNG
# Ukuran (Width x Height): (6000, 8000)
# Mode Warna: RGB
# Total Pixel: 48000000
# Shape: (8000, 6000, 3)
#
# Informasi Gambar Ground Truth: Img_061.png
# Format: PNG
# Ukuran (Width x Height): (3120, 4160)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (4160, 3120, 3)
#
# Informasi Gambar Ground Truth: Img_062.png
# Format: PNG
# Ukuran (Width x Height): (4160, 3120)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (3120, 4160, 3)
#
# Informasi Gambar Ground Truth: Img_063.png
# Format: PNG
# Ukuran (Width x Height): (3120, 4160)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (4160, 3120, 3)
#
# Informasi Gambar Ground Truth: Img_064.png
# Format: PNG
# Ukuran (Width x Height): (3120, 4160)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (4160, 3120, 3)
#
# Informasi Gambar Ground Truth: Img_065.png
# Format: PNG
# Ukuran (Width x Height): (3120, 4160)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (4160, 3120, 3)
#
# Informasi Gambar Ground Truth: Img_066.png
# Format: PNG
# Ukuran (Width x Height): (3120, 4160)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (4160, 3120, 3)
#
# Informasi Gambar Ground Truth: Img_067.png
# Format: PNG
# Ukuran (Width x Height): (4160, 3120)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (3120, 4160, 3)
#
# Informasi Gambar Ground Truth: Img_068.png
# Format: PNG
# Ukuran (Width x Height): (4160, 3120)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (3120, 4160, 3)
#
# Informasi Gambar Ground Truth: Img_069.png
# Format: PNG
# Ukuran (Width x Height): (3120, 4160)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (4160, 3120, 3)
#
# Informasi Gambar Ground Truth: Img_070.png
# Format: PNG
# Ukuran (Width x Height): (3120, 4160)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (4160, 3120, 3)
#
# Informasi Gambar Ground Truth: Img_071.png
# Format: PNG
# Ukuran (Width x Height): (3120, 4160)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (4160, 3120, 3)
#
# Informasi Gambar Ground Truth: Img_072.png
# Format: PNG
# Ukuran (Width x Height): (3120, 4160)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (4160, 3120, 3)
#
# Informasi Gambar Ground Truth: Img_073.png
# Format: PNG
# Ukuran (Width x Height): (3120, 4160)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (4160, 3120, 3)
#
# Informasi Gambar Ground Truth: Img_074.png
# Format: PNG
# Ukuran (Width x Height): (3120, 4160)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (4160, 3120, 3)
#
# Informasi Gambar Ground Truth: Img_075.png
# Format: PNG
# Ukuran (Width x Height): (3120, 4160)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (4160, 3120, 3)
#
# Informasi Gambar Ground Truth: Img_076.png
# Format: PNG
# Ukuran (Width x Height): (4160, 3120)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (3120, 4160, 3)
#
# Informasi Gambar Ground Truth: Img_077.png
# Format: PNG
# Ukuran (Width x Height): (4160, 3120)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (3120, 4160, 3)
#
# Informasi Gambar Ground Truth: Img_078.png
# Format: PNG
# Ukuran (Width x Height): (3120, 4160)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (4160, 3120, 3)
#
# Informasi Gambar Ground Truth: Img_079.png
# Format: PNG
# Ukuran (Width x Height): (3120, 4160)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (4160, 3120, 3)
#
# Informasi Gambar Ground Truth: Img_080.png
# Format: PNG
# Ukuran (Width x Height): (3120, 4160)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (4160, 3120, 3)
#
# Informasi Gambar Ground Truth: Img_081.png
# Format: PNG
# Ukuran (Width x Height): (3120, 4160)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (4160, 3120, 3)
#
# Informasi Gambar Ground Truth: Img_082.png
# Format: PNG
# Ukuran (Width x Height): (3120, 4160)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (4160, 3120, 3)
#
# Informasi Gambar Ground Truth: Img_083.png
# Format: PNG
# Ukuran (Width x Height): (3120, 4160)
# Mode Warna: RGB
# Total Pixel: 12979200
# Shape: (4160, 3120, 3)
#
# Informasi Gambar Ground Truth: Img_084.png
# Format: PNG
# Ukuran (Width x Height): (798, 940)
# Mode Warna: RGB
# Total Pixel: 750120
# Shape: (940, 798, 3)
#
# Informasi Gambar Ground Truth: Img_085.png
# Format: PNG
# Ukuran (Width x Height): (1024, 865)
# Mode Warna: RGB
# Total Pixel: 885760
# Shape: (865, 1024, 3)
#
# Informasi Gambar Ground Truth: Img_086.png
# Format: PNG
# Ukuran (Width x Height): (1024, 868)
# Mode Warna: RGB
# Total Pixel: 888832
# Shape: (868, 1024, 3)
#
# Informasi Gambar Ground Truth: Img_087.png
# Format: PNG
# Ukuran (Width x Height): (1024, 865)
# Mode Warna: RGB
# Total Pixel: 885760
# Shape: (865, 1024, 3)
#
# Informasi Gambar Ground Truth: Img_088.png
# Format: PNG
# Ukuran (Width x Height): (1024, 862)
# Mode Warna: RGB
# Total Pixel: 882688
# Shape: (862, 1024, 3)
#
# Informasi Gambar Ground Truth: Img_089.png
# Format: PNG
# Ukuran (Width x Height): (1024, 688)
# Mode Warna: RGB
# Total Pixel: 704512
# Shape: (688, 1024, 3)
#
# Informasi Gambar Ground Truth: Img_090.png
# Format: PNG
# Ukuran (Width x Height): (1024, 518)
# Mode Warna: RGB
# Total Pixel: 530432
# Shape: (518, 1024, 3)
#
# Informasi Gambar Ground Truth: Img_091.png
# Format: PNG
# Ukuran (Width x Height): (696, 502)
# Mode Warna: RGB
# Total Pixel: 349392
# Shape: (502, 696, 3)
#
# Informasi Gambar Ground Truth: Img_092.png
# Format: PNG
# Ukuran (Width x Height): (874, 438)
# Mode Warna: RGB
# Total Pixel: 382812
# Shape: (438, 874, 3)
#
# Informasi Gambar Ground Truth: Img_093.png
# Format: PNG
# Ukuran (Width x Height): (588, 500)
# Mode Warna: RGB
# Total Pixel: 294000
# Shape: (500, 588, 3)
#
# Informasi Gambar Ground Truth: Img_094.png
# Format: PNG
# Ukuran (Width x Height): (1024, 631)
# Mode Warna: RGB
# Total Pixel: 646144
# Shape: (631, 1024, 3)
#
# Informasi Gambar Ground Truth: Img_095.png
# Format: PNG
# Ukuran (Width x Height): (1024, 838)
# Mode Warna: RGB
# Total Pixel: 858112
# Shape: (838, 1024, 3)
#
# Informasi Gambar Ground Truth: Img_096.png
# Format: PNG
# Ukuran (Width x Height): (1024, 883)
# Mode Warna: RGB
# Total Pixel: 904192
# Shape: (883, 1024, 3)
#
# Informasi Gambar Ground Truth: Img_097.png
# Format: PNG
# Ukuran (Width x Height): (1024, 682)
# Mode Warna: RGB
# Total Pixel: 698368
# Shape: (682, 1024, 3)
#
# Informasi Gambar Ground Truth: Img_098.png
# Format: PNG
# Ukuran (Width x Height): (920, 506)
# Mode Warna: RGB
# Total Pixel: 465520
# Shape: (506, 920, 3)
#
# Informasi Gambar Ground Truth: Img_099.png
# Format: PNG
# Ukuran (Width x Height): (908, 504)
# Mode Warna: RGB
# Total Pixel: 457632
# Shape: (504, 908, 3)
#
# Informasi Gambar Ground Truth: Img_100.png
# Format: PNG
# Ukuran (Width x Height): (954, 502)
# Mode Warna: RGB
# Total Pixel: 478908
# Shape: (502, 954, 3)
#
# Informasi Gambar Ground Truth: Img_101.png
# Format: PNG
# Ukuran (Width x Height): (1024, 862)
# Mode Warna: RGB
# Total Pixel: 882688
# Shape: (862, 1024, 3)
#
# Informasi Gambar Ground Truth: Img_102.png
# Format: PNG
# Ukuran (Width x Height): (881, 758)
# Mode Warna: RGB
# Total Pixel: 667798
# Shape: (758, 881, 3)
#
# Informasi Gambar Ground Truth: Img_103.png
# Format: PNG
# Ukuran (Width x Height): (874, 856)
# Mode Warna: RGB
# Total Pixel: 748144
# Shape: (856, 874, 3)
#
# Informasi Gambar Ground Truth: Img_104.png
# Format: PNG
# Ukuran (Width x Height): (1024, 829)
# Mode Warna: RGB
# Total Pixel: 848896
# Shape: (829, 1024, 3)
#
# Informasi Gambar Ground Truth: Img_105.png
# Format: PNG
# Ukuran (Width x Height): (1024, 787)
# Mode Warna: RGB
# Total Pixel: 805888
# Shape: (787, 1024, 3)
#
# Informasi Gambar Ground Truth: Img_106.png
# Format: PNG
# Ukuran (Width x Height): (754, 658)
# Mode Warna: RGB
# Total Pixel: 496132
# Shape: (658, 754, 3)
#
# Informasi Gambar Ground Truth: Img_107.png
# Format: PNG
# Ukuran (Width x Height): (607, 796)
# Mode Warna: RGB
# Total Pixel: 483172
# Shape: (796, 607, 3)
#
# Informasi Gambar Ground Truth: Img_108.png
# Format: PNG
# Ukuran (Width x Height): (1024, 751)
# Mode Warna: RGB
# Total Pixel: 769024
# Shape: (751, 1024, 3)
#
# Informasi Gambar Ground Truth: Img_109.png
# Format: PNG
# Ukuran (Width x Height): (640, 512)
# Mode Warna: RGB
# Total Pixel: 327680
# Shape: (512, 640, 3)
#
# Informasi Gambar Ground Truth: Img_110.png
# Format: PNG
# Ukuran (Width x Height): (822, 424)
# Mode Warna: RGB
# Total Pixel: 348528
# Shape: (424, 822, 3)
#
# Informasi Gambar Ground Truth: Img_111.png
# Format: PNG
# Ukuran (Width x Height): (736, 438)
# Mode Warna: RGB
# Total Pixel: 322368
# Shape: (438, 736, 3)
#
# Informasi Gambar Ground Truth: Img_112.png
# Format: PNG
# Ukuran (Width x Height): (762, 316)
# Mode Warna: RGB
# Total Pixel: 240792
# Shape: (316, 762, 3)
#
# Informasi Gambar Ground Truth: Img_113.png
# Format: PNG
# Ukuran (Width x Height): (600, 715)
# Mode Warna: RGB
# Total Pixel: 429000
# Shape: (715, 600, 3)
#
# Informasi Gambar Ground Truth: Img_114.png
# Format: PNG
# Ukuran (Width x Height): (570, 664)
# Mode Warna: RGB
# Total Pixel: 378480
# Shape: (664, 570, 3)
#
# Informasi Gambar Ground Truth: Img_115.png
# Format: PNG
# Ukuran (Width x Height): (426, 696)
# Mode Warna: RGB
# Total Pixel: 296496
# Shape: (696, 426, 3)

# %% [markdown]
# # Preprocessing Data

# %%
import os
import shutil
from PIL import Image
import numpy as np
import cv2
import matplotlib.pyplot as plt

# Path ke folder
# Ensure base_dataset is defined correctly.
base_dataset = "C:\\Users\\Admin\\Documents\\SKRIPSI\\DATASET"
ori_folder = os.path.join(base_dataset, "ORI")
gt_folder = os.path.join(base_dataset, "GT")

# Defining target sizes
low = (128, 128)
standard = (256, 256)
high = (512, 512)

# Set the size and target for resizing
target = (256, 256)
# Output folder paths
base_preprocessed = os.path.join(base_dataset,"PREPROCESSING")
preprocessed_ori_data = os.path.join(base_preprocessed, "256\\prep_ori")
preprocessed_gt_data = os.path.join(base_preprocessed, "256\\prep_gt")
temp_ori_folder = os.path.join(base_dataset, "256\\temp_ori")  # Temporary folder for originals
temp_gt_folder = os.path.join(base_dataset, "256\\temp_gt")    # Temporary folder for ground truths

# Function to clear the output folder before processing
def clear_folder(folder_path):
    if os.path.exists(folder_path):
        for file in os.listdir(folder_path):
            file_path = os.path.join(folder_path, file)
            try:
                if os.path.isfile(file_path):
                    os.remove(file_path)  # Remove file
            except Exception as e:
                print(f"Error removing file {file_path}: {e}")

# Clear the output folders before saving new images
clear_folder(preprocessed_ori_data)
clear_folder(preprocessed_gt_data)

# Create output folders if they do not exist
os.makedirs(preprocessed_ori_data, exist_ok=True)
os.makedirs(preprocessed_gt_data, exist_ok=True)

# Create temporary folders for renaming
os.makedirs(temp_ori_folder, exist_ok=True)
os.makedirs(temp_gt_folder, exist_ok=True)

# Function to normalize images
def normalize_image(image):
    """Normalize the image to range [0, 1]."""
    image_array = np.array(image).astype(np.float32) / 255.0  # Normalize to [0, 1]
    return Image.fromarray((image_array * 255).astype(np.uint8))  # Convert back to Image


def copy_and_rename(src_folder, dst_folder, prefix):
    for i, filename in enumerate(sorted(os.listdir(src_folder)), start=1):
        old_file_path = os.path.join(src_folder, filename)
        if os.path.isfile(old_file_path) and "Img" in filename:
            # Rename the file
            ext = os.path.splitext(filename)[1]
            new_filename = f"{prefix}_{i:03d}{ext}"
            new_file_path = os.path.join(dst_folder, new_filename)

            # Copy the original file to the temporary folder with the new name
            shutil.copy2(old_file_path, new_file_path)
            print(f'Copied and renamed: {filename} -> {new_filename}')

# Function to preprocess images (both originals and masks)
def preprocess_images(src_folder, dst_folder, is_mask=False):
    processed_images = []
    file_list = sorted(os.listdir(src_folder))  # Ensure file order is consistent

    for filename in file_list:
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            img_path = os.path.join(src_folder, filename)
            try:
                with Image.open(img_path) as img:
                    if not is_mask:
                        # Preprocess original images
                        img = img.convert("RGB")  # Ensure RGB mode
                        img = img.resize(target, Image.Resampling.LANCZOS)
                        img = normalize_image(img)
                    else:
                        # Preprocess ground truth images (masks)
                        img = img.convert("RGB")  # Ensure RGB mode for masks
                        img = img.resize(target, Image.Resampling.NEAREST)  # Nearest interpolation to preserve class values
                        img = enhance_contrast_for_mask(img)  # Enhance contrast without creating gradients
                        img = threshold_colors(img)  # Threshold colors to remove noise

                    # Save the processed image with the modified filename and change the extension to PNG
                    new_filename = os.path.splitext(filename)[0] + '.png'  # Change the file extension to .png
                    img.save(os.path.join(dst_folder, new_filename), format='PNG')

                    # Store the image paths for example visualization
                    processed_images.append(os.path.join(dst_folder, new_filename))

            except Exception as e:
                print(f"Error processing file {filename}: {e}")

    return processed_images

# Function to enhance contrast for ground truth images without changing class values
def enhance_contrast_for_mask(image):
    """Enhance contrast for ground truth image while preserving class values."""
    image_array = np.array(image)
    unique_colors = np.unique(image_array.reshape(-1, image_array.shape[2]), axis=0)

    if len(unique_colors) <= 3:
        # Convert to grayscale and apply histogram equalization
        gray_image = cv2.cvtColor(image_array, cv2.COLOR_RGB2GRAY)
        enhanced_gray = cv2.equalizeHist(gray_image)

        # Create an enhanced image based on the original colors
        enhanced_mask = np.zeros_like(image_array)
        for color in unique_colors:
            mask = np.all(image_array == color, axis=-1)
            enhanced_mask[mask] = color  # Keep the original colors
    else:
        enhanced_mask = image_array  # Skip enhancement

    return Image.fromarray(enhanced_mask)

# Function to threshold colors in the mask
def threshold_colors(image):
    """Threshold the colors in the ground truth mask."""
    image_array = np.array(image)
    thresholded_image = np.where(image_array > 180, 255, 0).astype(np.uint8)  # Thresholding
    return Image.fromarray(thresholded_image)

# Copy and rename original images to the temporary folder
copy_and_rename(ori_folder, temp_ori_folder, prefix='ORI')

# Copy and rename ground truth images to the temporary folder
copy_and_rename(gt_folder, temp_gt_folder, prefix='GT')

# Preprocess renamed original images
preprocess_images(temp_ori_folder, preprocessed_ori_data, is_mask=False)

# Preprocess renamed ground truth images
preprocess_images(temp_gt_folder, preprocessed_gt_data, is_mask=True)

# Cleanup temporary folders if needed
shutil.rmtree(temp_ori_folder)
shutil.rmtree(temp_gt_folder)

print("Renaming and preprocessing completed.")
# Out:
# Copied and renamed: Img_001.png -> ORI_001.png
# Copied and renamed: Img_002.png -> ORI_002.png
# Copied and renamed: Img_003.png -> ORI_003.png
# Copied and renamed: Img_004.png -> ORI_004.png
# Copied and renamed: Img_005.png -> ORI_005.png
# Copied and renamed: Img_006.png -> ORI_006.png
# Copied and renamed: Img_007.png -> ORI_007.png
# Copied and renamed: Img_008.png -> ORI_008.png
# Copied and renamed: Img_009.png -> ORI_009.png
# Copied and renamed: Img_010.png -> ORI_010.png
# Copied and renamed: Img_011.png -> ORI_011.png
# Copied and renamed: Img_012.png -> ORI_012.png
# Copied and renamed: Img_013.png -> ORI_013.png
# Copied and renamed: Img_014.png -> ORI_014.png
# Copied and renamed: Img_015.png -> ORI_015.png
# Copied and renamed: Img_016.png -> ORI_016.png
# Copied and renamed: Img_017.png -> ORI_017.png
# Copied and renamed: Img_018.png -> ORI_018.png
# Copied and renamed: Img_019.png -> ORI_019.png
# Copied and renamed: Img_020.png -> ORI_020.png
# Copied and renamed: Img_021.png -> ORI_021.png
# Copied and renamed: Img_022.png -> ORI_022.png
# Copied and renamed: Img_023.png -> ORI_023.png
# Copied and renamed: Img_024.png -> ORI_024.png
# Copied and renamed: Img_025.png -> ORI_025.png
# Copied and renamed: Img_026.png -> ORI_026.png
# Copied and renamed: Img_027.png -> ORI_027.png
# Copied and renamed: Img_028.png -> ORI_028.png
# Copied and renamed: Img_029.png -> ORI_029.png
# Copied and renamed: Img_030.png -> ORI_030.png
# Copied and renamed: Img_031.png -> ORI_031.png
# Copied and renamed: Img_032.png -> ORI_032.png
# Copied and renamed: Img_033.png -> ORI_033.png
# Copied and renamed: Img_034.png -> ORI_034.png
# Copied and renamed: Img_035.png -> ORI_035.png
# Copied and renamed: Img_036.png -> ORI_036.png
# Copied and renamed: Img_037.png -> ORI_037.png
# Copied and renamed: Img_038.png -> ORI_038.png
# Copied and renamed: Img_039.png -> ORI_039.png
# Copied and renamed: Img_040.png -> ORI_040.png
# Copied and renamed: Img_041.png -> ORI_041.png
# Copied and renamed: Img_042.png -> ORI_042.png
# Copied and renamed: Img_043.png -> ORI_043.png
# Copied and renamed: Img_044.png -> ORI_044.png
# Copied and renamed: Img_045.png -> ORI_045.png
# Copied and renamed: Img_046.png -> ORI_046.png
# Copied and renamed: Img_047.png -> ORI_047.png
# Copied and renamed: Img_048.png -> ORI_048.png
# Copied and renamed: Img_049.png -> ORI_049.png
# Copied and renamed: Img_050.png -> ORI_050.png
# Copied and renamed: Img_051.png -> ORI_051.png
# Copied and renamed: Img_052.png -> ORI_052.png
# Copied and renamed: Img_053.png -> ORI_053.png
# Copied and renamed: Img_054.png -> ORI_054.png
# Copied and renamed: Img_055.png -> ORI_055.png
# Copied and renamed: Img_056.png -> ORI_056.png
# Copied and renamed: Img_057.png -> ORI_057.png
# Copied and renamed: Img_058.png -> ORI_058.png
# Copied and renamed: Img_059.png -> ORI_059.png
# Copied and renamed: Img_060.png -> ORI_060.png
# Copied and renamed: Img_061.png -> ORI_061.png
# Copied and renamed: Img_062.png -> ORI_062.png
# Copied and renamed: Img_063.png -> ORI_063.png
# Copied and renamed: Img_064.png -> ORI_064.png
# Copied and renamed: Img_065.png -> ORI_065.png
# Copied and renamed: Img_066.png -> ORI_066.png
# Copied and renamed: Img_067.png -> ORI_067.png
# Copied and renamed: Img_068.png -> ORI_068.png
# Copied and renamed: Img_069.png -> ORI_069.png
# Copied and renamed: Img_070.png -> ORI_070.png
# Copied and renamed: Img_071.png -> ORI_071.png
# Copied and renamed: Img_072.png -> ORI_072.png
# Copied and renamed: Img_073.png -> ORI_073.png
# Copied and renamed: Img_074.png -> ORI_074.png
# Copied and renamed: Img_075.png -> ORI_075.png
# Copied and renamed: Img_076.png -> ORI_076.png
# Copied and renamed: Img_077.png -> ORI_077.png
# Copied and renamed: Img_078.png -> ORI_078.png
# Copied and renamed: Img_079.png -> ORI_079.png
# Copied and renamed: Img_080.png -> ORI_080.png
# Copied and renamed: Img_081.png -> ORI_081.png
# Copied and renamed: Img_082.png -> ORI_082.png
# Copied and renamed: Img_083.png -> ORI_083.png
# Copied and renamed: Img_084.png -> ORI_084.png
# Copied and renamed: Img_085.png -> ORI_085.png
# Copied and renamed: Img_086.png -> ORI_086.png
# Copied and renamed: Img_087.png -> ORI_087.png
# Copied and renamed: Img_088.png -> ORI_088.png
# Copied and renamed: Img_089.png -> ORI_089.png
# Copied and renamed: Img_090.png -> ORI_090.png
# Copied and renamed: Img_091.png -> ORI_091.png
# Copied and renamed: Img_092.png -> ORI_092.png
# Copied and renamed: Img_093.png -> ORI_093.png
# Copied and renamed: Img_094.png -> ORI_094.png
# Copied and renamed: Img_095.png -> ORI_095.png
# Copied and renamed: Img_096.png -> ORI_096.png
# Copied and renamed: Img_097.png -> ORI_097.png
# Copied and renamed: Img_098.png -> ORI_098.png
# Copied and renamed: Img_099.png -> ORI_099.png
# Copied and renamed: Img_100.png -> ORI_100.png
# Copied and renamed: Img_101.png -> ORI_101.png
# Copied and renamed: Img_102.png -> ORI_102.png
# Copied and renamed: Img_103.png -> ORI_103.png
# Copied and renamed: Img_104.png -> ORI_104.png
# Copied and renamed: Img_105.png -> ORI_105.png
# Copied and renamed: Img_106.png -> ORI_106.png
# Copied and renamed: Img_107.png -> ORI_107.png
# Copied and renamed: Img_108.png -> ORI_108.png
# Copied and renamed: Img_109.png -> ORI_109.png
# Copied and renamed: Img_110.png -> ORI_110.png
# Copied and renamed: Img_111.png -> ORI_111.png
# Copied and renamed: Img_112.png -> ORI_112.png
# Copied and renamed: Img_113.png -> ORI_113.png
# Copied and renamed: Img_114.png -> ORI_114.png
# Copied and renamed: Img_115.png -> ORI_115.png
# Copied and renamed: Img_001.png -> GT_001.png
# Copied and renamed: Img_002.png -> GT_002.png
# Copied and renamed: Img_003.png -> GT_003.png
# Copied and renamed: Img_004.png -> GT_004.png
# Copied and renamed: Img_005.png -> GT_005.png
# Copied and renamed: Img_006.png -> GT_006.png
# Copied and renamed: Img_007.png -> GT_007.png
# Copied and renamed: Img_008.png -> GT_008.png
# Copied and renamed: Img_009.png -> GT_009.png
# Copied and renamed: Img_010.png -> GT_010.png
# Copied and renamed: Img_011.png -> GT_011.png
# Copied and renamed: Img_012.png -> GT_012.png
# Copied and renamed: Img_013.png -> GT_013.png
# Copied and renamed: Img_014.png -> GT_014.png
# Copied and renamed: Img_015.png -> GT_015.png
# Copied and renamed: Img_016.png -> GT_016.png
# Copied and renamed: Img_017.png -> GT_017.png
# Copied and renamed: Img_018.png -> GT_018.png
# Copied and renamed: Img_019.png -> GT_019.png
# Copied and renamed: Img_020.png -> GT_020.png
# Copied and renamed: Img_021.png -> GT_021.png
# Copied and renamed: Img_022.png -> GT_022.png
# Copied and renamed: Img_023.png -> GT_023.png
# Copied and renamed: Img_024.png -> GT_024.png
# Copied and renamed: Img_025.png -> GT_025.png
# Copied and renamed: Img_026.png -> GT_026.png
# Copied and renamed: Img_027.png -> GT_027.png
# Copied and renamed: Img_028.png -> GT_028.png
# Copied and renamed: Img_029.png -> GT_029.png
# Copied and renamed: Img_030.png -> GT_030.png
# Copied and renamed: Img_031.png -> GT_031.png
# Copied and renamed: Img_032.png -> GT_032.png
# Copied and renamed: Img_033.png -> GT_033.png
# Copied and renamed: Img_034.png -> GT_034.png
# Copied and renamed: Img_035.png -> GT_035.png
# Copied and renamed: Img_036.png -> GT_036.png
# Copied and renamed: Img_037.png -> GT_037.png
# Copied and renamed: Img_038.png -> GT_038.png
# Copied and renamed: Img_039.png -> GT_039.png
# Copied and renamed: Img_040.png -> GT_040.png
# Copied and renamed: Img_041.png -> GT_041.png
# Copied and renamed: Img_042.png -> GT_042.png
# Copied and renamed: Img_043.png -> GT_043.png
# Copied and renamed: Img_044.png -> GT_044.png
# Copied and renamed: Img_045.png -> GT_045.png
# Copied and renamed: Img_046.png -> GT_046.png
# Copied and renamed: Img_047.png -> GT_047.png
# Copied and renamed: Img_048.png -> GT_048.png
# Copied and renamed: Img_049.png -> GT_049.png
# Copied and renamed: Img_050.png -> GT_050.png
# Copied and renamed: Img_051.png -> GT_051.png
# Copied and renamed: Img_052.png -> GT_052.png
# Copied and renamed: Img_053.png -> GT_053.png
# Copied and renamed: Img_054.png -> GT_054.png
# Copied and renamed: Img_055.png -> GT_055.png
# Copied and renamed: Img_056.png -> GT_056.png
# Copied and renamed: Img_057.png -> GT_057.png
# Copied and renamed: Img_058.png -> GT_058.png
# Copied and renamed: Img_059.png -> GT_059.png
# Copied and renamed: Img_060.png -> GT_060.png
# Copied and renamed: Img_061.png -> GT_061.png
# Copied and renamed: Img_062.png -> GT_062.png
# Copied and renamed: Img_063.png -> GT_063.png
# Copied and renamed: Img_064.png -> GT_064.png
# Copied and renamed: Img_065.png -> GT_065.png
# Copied and renamed: Img_066.png -> GT_066.png
# Copied and renamed: Img_067.png -> GT_067.png
# Copied and renamed: Img_068.png -> GT_068.png
# Copied and renamed: Img_069.png -> GT_069.png
# Copied and renamed: Img_070.png -> GT_070.png
# Copied and renamed: Img_071.png -> GT_071.png
# Copied and renamed: Img_072.png -> GT_072.png
# Copied and renamed: Img_073.png -> GT_073.png
# Copied and renamed: Img_074.png -> GT_074.png
# Copied and renamed: Img_075.png -> GT_075.png
# Copied and renamed: Img_076.png -> GT_076.png
# Copied and renamed: Img_077.png -> GT_077.png
# Copied and renamed: Img_078.png -> GT_078.png
# Copied and renamed: Img_079.png -> GT_079.png
# Copied and renamed: Img_080.png -> GT_080.png
# Copied and renamed: Img_081.png -> GT_081.png
# Copied and renamed: Img_082.png -> GT_082.png
# Copied and renamed: Img_083.png -> GT_083.png
# Copied and renamed: Img_084.png -> GT_084.png
# Copied and renamed: Img_085.png -> GT_085.png
# Copied and renamed: Img_086.png -> GT_086.png
# Copied and renamed: Img_087.png -> GT_087.png
# Copied and renamed: Img_088.png -> GT_088.png
# Copied and renamed: Img_089.png -> GT_089.png
# Copied and renamed: Img_090.png -> GT_090.png
# Copied and renamed: Img_091.png -> GT_091.png
# Copied and renamed: Img_092.png -> GT_092.png
# Copied and renamed: Img_093.png -> GT_093.png
# Copied and renamed: Img_094.png -> GT_094.png
# Copied and renamed: Img_095.png -> GT_095.png
# Copied and renamed: Img_096.png -> GT_096.png
# Copied and renamed: Img_097.png -> GT_097.png
# Copied and renamed: Img_098.png -> GT_098.png
# Copied and renamed: Img_099.png -> GT_099.png
# Copied and renamed: Img_100.png -> GT_100.png
# Copied and renamed: Img_101.png -> GT_101.png
# Copied and renamed: Img_102.png -> GT_102.png
# Copied and renamed: Img_103.png -> GT_103.png
# Copied and renamed: Img_104.png -> GT_104.png
# Copied and renamed: Img_105.png -> GT_105.png
# Copied and renamed: Img_106.png -> GT_106.png
# Copied and renamed: Img_107.png -> GT_107.png
# Copied and renamed: Img_108.png -> GT_108.png
# Copied and renamed: Img_109.png -> GT_109.png
# Copied and renamed: Img_110.png -> GT_110.png
# Copied and renamed: Img_111.png -> GT_111.png
# Copied and renamed: Img_112.png -> GT_112.png
# Copied and renamed: Img_113.png -> GT_113.png
# Copied and renamed: Img_114.png -> GT_114.png
# Copied and renamed: Img_115.png -> GT_115.png
# Renaming and preprocessing completed.

# %%
import os
from PIL import Image

# Pastikan path dataset sudah sesuai
ori_folder = "C:\\Users\\Admin\\Documents\\SKRIPSI\\DATASET\\PREPROCESSING\\256\\prep_ori"
gt_folder = "C:\\Users\\Admin\\Documents\\SKRIPSI\\DATASET\\PREPROCESSING\\256\\prep_gt"

# Fungsi untuk mendapatkan informasi gambar
def get_image_info(folder_path):
    image_files = os.listdir(folder_path)
    resolutions = []
    color_modes = []
    formats = []

    for image_file in image_files:
        file_path = os.path.join(folder_path, image_file)
        with Image.open(file_path) as img:
            resolutions.append(img.size)
            color_modes.append(img.mode)
            formats.append(img.format)

    return {
        "total_images": len(image_files),
        "resolution": set(resolutions),
        "color_mode": set(color_modes),
        "file_format": set(formats)
    }

# Informasi dataset original
ori_info = get_image_info(ori_folder)
print(f"\nJumlah data di folder original: {ori_info['total_images']}")
print(f"Resolusi gambar di folder original: {ori_info['resolution']}")
print(f"Format warna gambar di folder original: {ori_info['color_mode']}")
print(f"Format file di folder original: {ori_info['file_format']}")

# Informasi dataset ground truth
gt_info = get_image_info(gt_folder)
print(f"\nJumlah data di folder ground_truth: {gt_info['total_images']}")
print(f"Resolusi gambar di folder ground_truth: {gt_info['resolution']}")
print(f"Format warna gambar di folder ground_truth: {gt_info['color_mode']}")
print(f"Format file di folder ground_truth: {gt_info['file_format']}")
# Out:
# Jumlah data di folder original: 115
# Resolusi gambar di folder original: {(256, 256)}
# Format warna gambar di folder original: {'RGB'}
# Format file di folder original: {'PNG'}
#
# Jumlah data di folder ground_truth: 115
# Resolusi gambar di folder ground_truth: {(256, 256)}
# Format warna gambar di folder ground_truth: {'RGB'}
# Format file di folder ground_truth: {'PNG'}
